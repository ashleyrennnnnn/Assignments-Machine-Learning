# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("pre-processed-data.csv")
data
# Out:
#       gwb_code_10  a_inw  a_man  a_vrouw  a_00_14  a_15_24  a_25_44  a_45_64  \
# 0          GM0003  11721   5720     6001     1718     1238     2376     3491
# 1        WK000300  11720   5720     6000     1715     1235     2375     3490
# 2      BU00030000   2370   1135     1230      230      225      500      715
# 3      BU00030001   3035   1505     1530      480      350      570      990
# 4      BU00030002   5725   2760     2960      900      580     1205     1560
# ...           ...    ...    ...      ...      ...      ...      ...      ...
# 17108    WK197820    715    360      355      125      110      120      205
# 17109  BU19782001     10      5        5        5        5        0        5
# 17110  BU19782002    440    225      215       60       70       80      135
# 17111  BU19782003    150     70       80       40       20       20       40
# 17112  BU19782004    115     60       60       25       15       20       35
#
# ...

# %%
# Out:
# g_afs_hp      3.939
# g_afs_gs      3.939
# g_afs_kv      3.939
# ste_oad       0.012
# sporting      5.762
# loneliness    5.762
# dtype: float64
